# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("/content/Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df['area'].max()
# Out:
# 16200

# %%
df['bedrooms'].max()
# Out:
# 6

# %%
df['bathrooms'].max()
# Out:
# 4

# %%
df['parking'].max()
# Out:
# 3

# %%
df['stories'].max()
# Out:
# 4

# %%
df['new']=df['bathrooms']+df['bathrooms']+df['stories']+df['parking']

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
areaavg=df['area'].mean()
areaavg
# Out:
# 5150.54128440367

# %%
newavg=df['new'].mean()
newavg
# Out:
# 5.0715596330275226

# %%
ratio=areaavg/newavg

# %%
ratio
# Out:
# 1015.5734442836471

# %%
df['House_Area']=df['area']/df['new']
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
dataset=df.drop(['bedrooms','stories','parking','new'],axis=1)
dataset
# Out:
#         price  area  bathrooms mainroad guestroom basement hotwaterheating  \
# 0    13300000  7420          2      yes        no       no              no
# 1    12250000  8960          4      yes        no       no              no
# 2    12250000  9960          2      yes        no      yes              no
# 3    12215000  7500          2      yes        no      yes              no
# 4    11410000  7420          1      yes       yes      yes              no
# ..        ...   ...        ...      ...       ...      ...             ...
# 540   1820000  3000          1      yes        no      yes              no
# 541   1767150  2400          1       no        no       no              no
# 542   1750000  3620          1      yes        no       no              no
# 543   1750000  2910          1       no        no       no              no
# 544   1750000  3850          1      yes        no       no              no
#
#     airconditioning prefarea furnishingstatus   House_Area
# ...

# %%
X=dataset.drop('price',axis=1)
X=X.drop('furnishingstatus',axis=1)
scaler = StandardScaler()
X['mainroad'] = X['mainroad'].map({'yes': 1, 'no': 0})
X['guestroom'] = X['guestroom'].map({'yes': 1, 'no': 0})
X['basement'] = X['basement'].map({'yes': 1, 'no': 0})
X['hotwaterheating'] = X['hotwaterheating'].map({'yes': 1, 'no': 0})
X['airconditioning'] = X['airconditioning'].map({'yes': 1, 'no': 0})
X['prefarea'] = X['prefarea'].map({'yes': 1, 'no': 0})
X = scaler.fit_transform(X)
Y= dataset['price'].values
Y=np.log1p(Y)
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=2)

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.FloatTensor(X_train)
y_train_tensor = torch.FloatTensor(y_train).view(-1, 1)  # Reshape to a column vector
X_test_tensor = torch.FloatTensor(X_test)
y_test_tensor = torch.FloatTensor(y_test).view(-1, 1)  # Reshape to a column vector

# Define the neural network model
class HousePricePredictor(nn.Module):
    def __init__(self, input_size, hidden_size1,hidden_size2, output_size):
        super(HousePricePredictor, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size1)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(hidden_size1, hidden_size2)
        self.layer3 = nn.Linear(hidden_size2, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.relu(x)
        x = self.layer2(x)
        x = self.layer3(x)
        return x

# Instantiate the model
input_size = X_train.shape[1]
hidden_size1 = 16  # Adjust as needed
hidden_size2=8
output_size = 1
model = HousePricePredictor(input_size, hidden_size1,hidden_size2, output_size)

# Define the loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training the model
num_epochs = 10000

for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Print progress
    if (epoch + 1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# Evaluate the model on the test set
with torch.no_grad():
    model.eval()
    predictions = model(X_test_tensor)
    mse = mean_squared_error(y_test, predictions.numpy())
    print(f'Mean Squared Error on Test Set: {mse:.4f}')
# Out:
# Epoch [100/10000], Loss: 168.8221
# Epoch [200/10000], Loss: 32.4609
# Epoch [300/10000], Loss: 8.6099
# Epoch [400/10000], Loss: 4.9083
# Epoch [500/10000], Loss: 2.9956
# Epoch [600/10000], Loss: 1.9362
# Epoch [700/10000], Loss: 1.3744
# Epoch [800/10000], Loss: 1.0199
# Epoch [900/10000], Loss: 0.7941
# Epoch [1000/10000], Loss: 0.6339
# Epoch [1100/10000], Loss: 0.5195
# Epoch [1200/10000], Loss: 0.4309
# Epoch [1300/10000], Loss: 0.3566
# Epoch [1400/10000], Loss: 0.2925
# Epoch [1500/10000], Loss: 0.2395
# Epoch [1600/10000], Loss: 0.2006
# Epoch [1700/10000], Loss: 0.1734
# Epoch [1800/10000], Loss: 0.1525
# Epoch [1900/10000], Loss: 0.1356
# Epoch [2000/10000], Loss: 0.1225
# Epoch [2100/10000], Loss: 0.1119
# Epoch [2200/10000], Loss: 0.1034
# Epoch [2300/10000], Loss: 0.0964
# Epoch [2400/10000], Loss: 0.0907
# Epoch [2500/10000], Loss: 0.0856
# Epoch [2600/10000], Loss: 0.0812
# Epoch [2700/10000], Loss: 0.0773
# Epoch [2800/10000], Loss: 0.0739
# ...

# %%
from sklearn.metrics import r2_score


# Convert data to PyTorch tensors
X_train_tensor = torch.FloatTensor(X_train)
y_train_tensor = torch.FloatTensor(y_train).view(-1, 1)  # Reshape to a column vector
X_test_tensor = torch.FloatTensor(X_test)
y_test_tensor = torch.FloatTensor(y_test).view(-1, 1)  # Reshape to a column vector

# Define the neural network model
class HousePricePredictor(nn.Module):
    def __init__(self, input_size, hidden_size1,hidden_size2, output_size):
        super(HousePricePredictor, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size1)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(hidden_size1, hidden_size2)
        self.layer3 = nn.Linear(hidden_size2, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.relu(x)
        x = self.layer2(x)
        x = self.layer3(x)
        return x

# Instantiate the model
input_size = X_train.shape[1]
hidden_size1 = 16  # Adjust as needed
hidden_size2=8
output_size = 1
model = HousePricePredictor(input_size, hidden_size1,hidden_size2, output_size)

# Define the loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training the model
num_epochs = 5000

for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Print progress
    if (epoch + 1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# Evaluate the model on the test set
with torch.no_grad():
    model.eval()
    predictions = model(X_test_tensor)
    mse = mean_squared_error(y_test, predictions.numpy())
    print(f'Mean Squared Error on Test Set: {mse:.4f}')
# Evaluate the model on the test set
with torch.no_grad():
    model.eval()
    predictions = model(X_test_tensor)

    # Calculate R-squared
    r2 = r2_score(y_test, predictions.numpy())
    print(f'R-squared on Test Set: {r2:.4f}')

# Function to predict house price using the trained model
def predict_house_price(model, input_features, scaler):
    # Standardize input features using the same scaler used for training
    input_features_standardized = scaler.transform(input_features)

    # Convert to PyTorch tensor
    input_tensor = torch.FloatTensor(input_features_standardized)

    # Make the prediction
    with torch.no_grad():
        model.eval()
        predicted_price = model(input_tensor)

    return predicted_price.item()

# Example usage:
# Replace the values in the input_features array with your own input values
input_features = np.array([[3000, 1, 0,
                            1, 0, 0,
                            0, 0, 600]])


# Use the predict_house_price function
predicted_price = predict_house_price(model, input_features, scaler)

print(f'Predicted House Price: {predicted_price:.2f}')
# Out:
# Epoch [100/5000], Loss: 191.1612
# Epoch [200/5000], Loss: 50.8008
# Epoch [300/5000], Loss: 8.4452
# Epoch [400/5000], Loss: 4.2448
# Epoch [500/5000], Loss: 2.5802
# Epoch [600/5000], Loss: 1.6824
# Epoch [700/5000], Loss: 1.1651
# Epoch [800/5000], Loss: 0.8629
# Epoch [900/5000], Loss: 0.6750
# Epoch [1000/5000], Loss: 0.5487
# Epoch [1100/5000], Loss: 0.4550
# Epoch [1200/5000], Loss: 0.3828
# Epoch [1300/5000], Loss: 0.3303
# Epoch [1400/5000], Loss: 0.2873
# Epoch [1500/5000], Loss: 0.2514
# Epoch [1600/5000], Loss: 0.2228
# Epoch [1700/5000], Loss: 0.1989
# Epoch [1800/5000], Loss: 0.1791
# Epoch [1900/5000], Loss: 0.1629
# Epoch [2000/5000], Loss: 0.1486
# Epoch [2100/5000], Loss: 0.1363
# Epoch [2200/5000], Loss: 0.1253
# Epoch [2300/5000], Loss: 0.1160
# Epoch [2400/5000], Loss: 0.1075
# Epoch [2500/5000], Loss: 0.0997
# Epoch [2600/5000], Loss: 0.0926
# Epoch [2700/5000], Loss: 0.0868
# Epoch [2800/5000], Loss: 0.0812
# Epoch [2900/5000], Loss: 0.0767
# ...

# %%
X
# Out:
# array([[ 1.04672629,  1.42181174,  0.40562287, ...,  1.4726183 ,
#          1.80494113, -0.52454873],
#        [ 1.75700953,  5.40580863,  0.40562287, ...,  1.4726183 ,
#         -0.55403469, -0.96099744],
#        [ 2.21823241,  1.42181174,  0.40562287, ..., -0.67906259,
#          1.80494113,  0.28365009],
#        ...,
#        [-0.70592066, -0.57018671,  0.40562287, ..., -0.67906259,
#         -0.55403469,  0.20998335],
#        [-1.03338891, -0.57018671, -2.46534421, ..., -0.67906259,
#         -0.55403469, -0.24482866],
#        [-0.5998394 , -0.57018671,  0.40562287, ..., -0.67906259,
#         -0.55403469, -0.25924172]])
